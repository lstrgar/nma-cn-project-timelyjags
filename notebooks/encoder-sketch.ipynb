# %%
import torch
import torch.nn as nn
from torchvision import models
from torch.utils.data import DataLoader, Dataset
import numpy as np, os
from glob import glob

# %%
vidspath = "/Users/luke/Desktop/participants_data/AlgonautsVideos268_All_30fpsmax/"
fmrispath = "/Users/luke/Desktop/participants_data/participants_data_v2021/mini_track/"

# %%
vidpaths = glob(os.path.join(vidspath, "*"))
fmrisubjs = glob(os.path.join(fmrispath, "*"))

# %%
class AlgonautVideoDataset(Dataset):
    def __init__(self, video_dir):
        self.video_dir = video_dir
        
    def __len__(self):
        return 0
    
    def __getitem__(self, idx):
        return 0

# %%
class FrameEncoder(nn.Module):
    def __init__(self, pretrained=False, out_features=1024):
        super(FrameEncoder, self).__init__()
        self.net = models.resnet50(pretrained=pretrained, download=True)
        self.net.fc = nn.Linear(in_features=net.fc.in_features, out_features=out_features)
            
    def forward(self, x):
        return self.net(x)
    
class VideoEncoder(nn.Module):
    def __init__(
        self,
        out_features=1024,
        pretrained=False,
        bidirectional=False,
        num_layers=1,
        hidden_size=1024,
    ):
        super(VideoEncoder, self).__init__()
        self.frame_encoder = FrameEncoder(pretrained=pretrained, out_features=out_features)
        self.rnn = nn.LSTM(
            batch_first=False,
            bidirectional=birdirectional,
            num_layers=1,
            input_size=out_features,
            hidden_size=hidden_size
        )
        
    def forward(self, x):
        ## x starts as (frames, C, H, W)
        x = self.frame_encoder(x)
        x = torch.unsqueeze(x, 1)
        ## x is now (frames, 1, out_features)
        _, hidden = self.rnn(input=x)
        return hidden ## (frames, 1, num_directions * hidden_size)

# %%
net = models.resnet50()

# %%
net
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...
